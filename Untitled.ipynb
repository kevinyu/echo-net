# %%
import numpy as np
import matplotlib.pyplot as plt
from echo.network import ReservoirState, Reservoir, ReservoirNetwork

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def pulses(N, pulse_size, n=100):
    y = np.zeros(N)
    for i in range(N//n):
        y[i*n:i*n+n] = np.random.choice([1, 2, 0, -1, -2])
    return y

# %%
def pulse(total_duration, pulse_start, pulse_duration, dt=0.1):
    result = np.zeros(int(total_duration / dt))
    n = int(pulse_duration / dt)
    idx_start = int(pulse_start / dt)
    result[idx_start:idx_start + n] = 5
    return result

# %%
res = Reservoir(800, N_in=2, N_out=1, sparsity=0.25, g=1.8, noise=0.1, feedback_on=1.0)

# %%
plt.imshow(res.W_recurrent.toarray())
plt.clim(-1, 1)
plt.colorbar()
plt.title(r"$W_{recurrent}$")
plt.show()

# %%
sys = ReservoirNetwork(res)

# %% [markdown]
# First lets drive it with no input (1000 timesteps)

# %%
null_input_result = sys.run(input_data=np.zeros((2, 5000)))

# %%
plt.plot(null_input_result["r"].T[:, :5])
plt.title("No input")
plt.show()

# %% [markdown]
# Next with a sine wave

# %%
always = ReservoirState(np.random.normal(size=(800, 1)))

# %%
t = np.linspace(0, 100, 20000)
sin = np.zeros((2, 20000))
sin[0, :] = np.sin(2 * np.pi * 2.0 * t)
sinehi_input_result = sys.run(input_data=sin, state=always)

# %%
plt.plot(sinehi_input_result["r"].T[:, :5])
plt.title("High frequency input")
plt.show()

# %%
t = np.linspace(0, 100, 20000)
sin[0, :] = np.sin(2 * np.pi * 0.1 * t)
sinelo_input_result = sys.run(input_data=sin, state=always)

# %%
plt.plot(sinelo_input_result["r"].T[:, :3])
plt.show()
plt.plot(sin[0])
plt.plot(sinelo_input_result["z"].T)
plt.show()

# %%
t = np.linspace(0, 100, 20000)
sin[0, :] = np.sin(2 * np.pi * 0.01 * t)
sineverylo_input_result = sys.run(input_data=sin, state=always)

# %%
plt.plot(sineverylo_input_result["r"].T[:, :5])
plt.show()
plt.plot(sin[0])
plt.plot(sineverylo_input_result["z"].T)
plt.show()

# %% [markdown]
# Now with random pulses

# %%
t = np.linspace(0, 100, 10000)
p = np.zeros((2, 10000))
p[0, :] = pulses(10000, 1000, n=500)
pulses_500 = sys.run(p, state=always)

# %%
plt.subplot(2, 1, 1)
plt.plot(p[0])
plt.xlim(0, 6000)

plt.subplot(2, 1, 2)
plt.plot(pulses_500["r"].T[:, :5])
plt.xlim(0, 6000)
plt.show()

# %%
t = np.linspace(0, 100, 10000)
p = np.zeros((2, 10000))
p[0, :] = pulses(10000, 1000, n=100)
pulses_100 = sys.run(p, state=always)

# %%
plt.subplot(3, 1, 1)
plt.plot(p[0][3000:6000])
plt.subplot(3, 1, 2)
plt.plot(pulses_100["r"].T[3000:6000, :5])
plt.subplot(3, 1, 3)
plt.plot(pulses_100["z"].T[3000:6000, :])
plt.tight_layout()
plt.show()

# %%
teaching_result = sys.teach(p, p[:1, :] ** 2, state=always)
# Out:
# Finished learning

# %%
pulses_taught = sys.run(p, state=always)

# %%
plt.subplot(3, 1, 1)
plt.plot(p[0][3000:6000])
plt.subplot(3, 1, 2)
plt.plot(pulses_taught["r"].T[3000:6000, :])
plt.subplot(3, 1, 3)
plt.plot(pulses_taught["z"].T[3000:6000, :])
plt.tight_layout()
plt.show()

# %%
input_pulse = pulse(3000.0, 500.0, 10.0, dt=0.1) + pulse(3000.0, 2000.0, 10.0, dt=0.1)
# input_pulse = np.vstack((pulse(3000.0, 500.0, 10.0, dt=0.1), pulse(3000.0, 500.0, 10.0, dt=0.1)))
bleh = np.zeros((2, input_pulse.size))
bleh[0, :] = input_pulse

# %%
pulse_result = sys.run(bleh, state=always)

# %%
plt.subplot(3, 1, 1)
plt.plot(bleh[0])
plt.subplot(3, 1, 2)
plt.plot(pulse_result["r"].T[:, :5])
plt.subplot(3, 1, 3)
plt.plot(pulse_result["z"].T[:, :])
plt.tight_layout()
plt.show()

# %%
input_pulse = pulse(3000.0, 505.0, 10.0, dt=0.1) + pulse(3000.0, 2000.0, 30.0, dt=0.1)
# input_pulse = np.vstack((pulse(3000.0, 500.0, 10.0, dt=0.1), pulse(3000.0, 500.0, 10.0, dt=0.1)))
bleh = np.zeros((2, input_pulse.size))
bleh[0, :] = input_pulse

# %%
pulse_result = sys.run(bleh, state=always)
pulse_result2 = sys.run(bleh, state=always)

# %%
plt.subplot(3, 1, 1)
plt.plot(bleh[0])
plt.subplot(3, 1, 2)
plt.plot(pulse_result["r"].T[:, :2])
plt.plot(pulse_result2["r"].T[:, :2])

plt.subplot(3, 1, 3)
plt.plot(pulse_result["z"].T[:, :])
plt.plot(pulse_result2["z"].T[:, :])

plt.tight_layout()
plt.show()

# %%
# use teach to learn a function
# implement an online learning
# plotting tools: animate activations in grid
# api

# initial_state = ReservoirState()
# net = Network()
# net.run(input)   # input should be N_inputs x N_samples
# net.train(input, target)  # target should be N_outputs x N_samples
# net.run

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
null_input_result1 = sys.run(input_data=np.zeros((2, 5000)), state=always)
null_input_result2 = sys.run(input_data=np.zeros((2, 5000)), state=always)
null_input_result3 = sys.run(input_data=np.zeros((2, 5000)), state=always)

# %%
dats1 = pca.fit_transform(null_input_result1["r"].T)
dats2 = pca.fit_transform(null_input_result2["r"].T)
dats3 = pca.fit_transform(null_input_result3["r"].T)

# %%
plt.plot(dats1[:, 0], dats1[:, 1])
plt.plot(dats2[:, 0], dats2[:, 1])
plt.plot(dats3[:, 0], dats3[:, 1])

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
pca = PCA(n_components=3)

dats1 = pca.fit_transform(null_input_result1["r"].T)
dats2 = pca.fit_transform(null_input_result2["r"].T)
dats3 = pca.fit_transform(null_input_result3["r"].T)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(dats1[0, 0], dats1[0, 1], dats1[0, 2])
ax.scatter(dats2[0, 0], dats2[0, 1], dats2[0, 2])
ax.scatter(dats3[0, 0], dats3[0, 1], dats3[0, 2])

ax.plot(dats1[:, 0], dats1[:, 1], dats1[:, 2])
ax.plot(dats2[:, 0], dats2[:, 1], dats2[:, 2])
ax.plot(dats3[:, 0], dats3[:, 1], dats3[:, 2])

plt.show()
# Out:
# <img src="data:image/png;base64,...">
